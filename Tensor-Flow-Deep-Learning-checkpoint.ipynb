# %%
import pandas as pd
import tensorflow as tf

# %%
df = pd.read_csv("C:/Users/arodr/Documents/bootcamp/nu-chi-data-pt-04-2021-u-c/02-Homework/21-Machine-Learning/Instructions/starter_code/exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
# Set features. This will also be used as your x values.
# selected_features = df[['names', 'of', 'selected', 'features', 'here']]
selected_features = df.drop("koi_disposition", axis=1)

# %%
y = df["koi_disposition"]
print(selected_features.shape, y.shape)
# Out:
# (6991, 40) (6991,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical
X_train, X_test, y_train, y_test = train_test_split(selected_features, y, random_state=1)
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 3563              0              0              0              0   10.548413
# 4099              0              0              0              0   24.754385
# 5460              0              0              0              0    1.057336
# 1091              0              0              0              0  201.118319
# 5999              0              0              0              0   91.649983
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 3563     5.470000e-05    -5.470000e-05   139.064020          0.004110
# 4099     1.365000e-04    -1.365000e-04   140.207320          0.004460
# 5460     1.230000e-07    -1.230000e-07   131.792007          0.000096
# 1091     1.461000e-03    -1.461000e-03   187.569860          0.005290
# 5999     3.181000e-03    -3.181000e-03   175.715600          0.028600
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
# Scale your data
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# %%
# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Create model and add layers
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=40))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=3, activation='softmax'))

# Compile and fit the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# model.summary()

model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=60,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/60
# 164/164 - 1s - loss: 0.5728 - accuracy: 0.7208
# Epoch 2/60
# 164/164 - 0s - loss: 0.3813 - accuracy: 0.8018
# Epoch 3/60
# 164/164 - 0s - loss: 0.3608 - accuracy: 0.8154
# Epoch 4/60
# 164/164 - 0s - loss: 0.3543 - accuracy: 0.8240
# Epoch 5/60
# 164/164 - 0s - loss: 0.3513 - accuracy: 0.8304
# Epoch 6/60
# 164/164 - 0s - loss: 0.3362 - accuracy: 0.8402
# Epoch 7/60
# 164/164 - 0s - loss: 0.3364 - accuracy: 0.8426
# Epoch 8/60
# 164/164 - 0s - loss: 0.3353 - accuracy: 0.8379
# Epoch 9/60
# 164/164 - 0s - loss: 0.3228 - accuracy: 0.8476
# Epoch 10/60
# 164/164 - 0s - loss: 0.3221 - accuracy: 0.8489
# Epoch 11/60
# 164/164 - 0s - loss: 0.3162 - accuracy: 0.8520
# Epoch 12/60
# 164/164 - 0s - loss: 0.3086 - accuracy: 0.8604
# Epoch 13/60
# 164/164 - 0s - loss: 0.3095 - accuracy: 0.8636
# Epoch 14/60
# 164/164 - 0s - loss: 0.3022 - accuracy: 0.8669
# Epoch 15/60
# 164/164 - 0s - loss: 0.3003 - accuracy: 0.8638
# Epoch 16/60
# 164/164 - 0s - loss: 0.3090 - accuracy: 0.8575
# ...

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2578 - accuracy: 0.8919
# Normal Neural Network - Loss: 0.25781571865081787, Accuracy: 0.8918764591217041

# %%
encoded_predictions = (model.predict(X_test) > 0.5).astype("int32")
prediction_labels = X_train, X_test, y_train, y_test = train_test_split(X_test, y_test, test_size = 0.3)
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:5])}")
# Out:
# Predicted classes: [      koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 4239              0              0              1              1    1.332565
# 3733              0              0              0              1    2.404412
# 3216              0              0              0              0    5.682516
# 6339              1              0              0              0  379.631350
# 1264              0              0              0              0    5.037280
# ...             ...            ...            ...            ...         ...
# 2351              0              0              0              0    9.668574
# 5253              0              0              0              0   20.956998
# 2699              0              0              0              0    7.751928
# 4563              1              0              0              0  116.170346
# 4109              0              0              1              0    1.306985
#
# ...

# %%
model.save("DeepLearning_model.h5")
